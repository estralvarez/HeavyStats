# %%
from heavystats.cleaning import get_analytical_sample
import pandas as pd

df = pd.read_csv("../data/muestra_metales_pesados_23_07_2026.csv", sep= ";", encoding= "latin1", )

df_p = df
df_s = get_analytical_sample(df)
